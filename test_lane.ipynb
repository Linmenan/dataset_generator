# %%
# %gui qt

from src.lane_simulation.lane_simulator import LaneSimulator
from src.scene_simulation.scene_simulator import SceneSimulator,Mode
from pyqtgraph.Qt import QtWidgets
import time
# oxdr 数据
# file_path = "./road_map/parking1.xodr"
# file_path = "./road_map/parking2.xodr"
# file_path = "./road_map/parking3.xodr"
file_path = "./road_map/Town10HD_Opt.xodr"
# yaml_path = "./config/traffic_signals/parking1.yaml"
yaml_path = "./config/traffic_signals/Town10HD_Opt.yaml"

# 设置当前位置与感知范围
current_position = (0.0, 0.0)  # 例如：x=100米, y=200米
sensing_range = 30.0  # 例如：50米感知半径
# scene_simulator = SceneSimulator(step=0.1, plot_step=1, mode=Mode.SYNC,map_file_path = file_path, 


lane_simulator = LaneSimulator(map_file_path = file_path, yaml_path=yaml_path, perception_range = sensing_range)

result = lane_simulator.radius_query([100,10],50)

print(len(result))
# Out:
# 原子化删除操作
# 删除: road_network_idx.dat
# 删除: road_network_idx.idx
# lane init
# 车道数量： 168
# 检索到车道数量： 32
# 最小距离： 41.99468203349868
# 成功
# 最小距离： 38.81457375040532
# 成功
# 最小距离： 31.79910827427972
# 成功
# 最小距离： 28.891194218487463
# 成功
# 最小距离： 0.8236057808610552
# 成功
# 最小距离： 0.5658546530674405
# 成功
# 最小距离： 12.767980864471872
# 成功
# 最小距离： 2.994602153956733
# 成功
# 最小距离： 2.934196153397507
# 成功
# 最小距离： 13.050630508384275
# 成功
# 最小距离： 6.461962367477614
# 成功
# 最小距离： 6.434191685427736
# 成功
# 最小距离： 14.216771010930046
# 成功
# 最小距离： 9.952199416054297
# 成功
# 最小距离： 9.934190365754127
# 成功
# 最小距离： 16.07526669415072
# 成功
# 最小距离： 6.23979966301586
# 成功
# 最小距离： 5.535863460776308
# 成功
# 最小距离： 8.469026827964795
# 成功
# 最小距离： 11.358421148689729
# 成功
# 最小距离： 39.85754706731015
# 成功
# 最小距离： 24.63925393890604
# 成功
# 最小距离： 28.116535868270503
# 成功
# 最小距离： 39.953572824342935
# 成功
# 最小距离： 11.35842114868973
# 成功
# 最小距离： 8.469026827964798
# 成功
# 最小距离： 5.535863460776314
# 成功
# 最小距离： 57.312092389625
# 最小距离： 55.02448319073892
# 最小距离： 57.312092389625
# 最小距离： 50.32202203828479
# 最小距离： 48.53682847439271
# 成功
# 28
